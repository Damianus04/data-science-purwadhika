# %% [markdown]
# # Import Libraries

# %%
# Default
import numpy as np
import pandas as pd

def desc(df):
    dataDesc = []

    for i in df.columns:
        dataDesc.append([
            i,
            df[i].dtypes,
            df[i].isna().sum(),
            round((((df[i].isna().sum()) / len(df)) * 100), 2),
            df[i].nunique(),
            df[i].drop_duplicates().sample(2).values
        ])

    description = pd.DataFrame(dataDesc, columns=[
        'Data Feature',
        'Data Types',
        'Null',
        'Null Percentage',
        'Unique',
        'Unique Sample'
    ])

    return description

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# #### 1) Untuk feature/column Landsize & Price, hitung dan beri penjelasan (insight) terkait:
#
# - Titik Pusat Data (Central Tendency)
# - Persebaran Data (Dispersion)
# - Distribusi Data (Distribution)

# %%
sns.scatterplot(data=df, x='Landsize', y='Price', hue='Landsize')

plt.title('Scatter Plot: Landsize & Price', size=15)

plt.show()

# %% [markdown]
# - Titik Pusat Data
#     - Central tendency data Price ada di angka 1075684.0
#     - Central tendency data Landsize ada di angka 558.0
# - Sebaran datanya terpusat di landsize di bawah 50,000 dan harga di bawah 2,000,000
# - Distribusinya hampir menyerupai distribusi normal

# %%
df.describe().round()
# Out:
#          Rooms      Price  Distance  Postcode  Bedroom2  Bathroom      Car  \
# count  13580.0    13580.0   13580.0   13580.0   13580.0   13580.0  13518.0
# mean       3.0  1075684.0      10.0    3105.0       3.0       2.0      2.0
# std        1.0   639311.0       6.0      91.0       1.0       1.0      1.0
# min        1.0    85000.0       0.0    3000.0       0.0       0.0      0.0
# 25%        2.0   650000.0       6.0    3044.0       2.0       1.0      1.0
# 50%        3.0   903000.0       9.0    3084.0       3.0       1.0      2.0
# 75%        3.0  1330000.0      13.0    3148.0       3.0       2.0      2.0
# max       10.0  9000000.0      48.0    3977.0      20.0       8.0     10.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# count   13580.0        7130.0     8205.0    13580.0     13580.0
# mean      558.0         152.0     1965.0      -38.0       145.0
# std      3991.0         541.0       37.0        0.0         0.0
# min         0.0           0.0     1196.0      -38.0       144.0
# 25%       177.0          93.0     1940.0      -38.0       145.0
# 50%       440.0         126.0     1970.0      -38.0       145.0
# 75%       651.0         174.0     1999.0      -38.0       145.0
# max    433014.0       44515.0     2018.0      -37.0       146.0
#
#        Propertycount  YearBuiltInt
# count        13580.0       13580.0
# mean          7454.0        1187.0
# std           4379.0         961.0
# min            249.0           0.0
# 25%           4380.0           0.0
# 50%           6555.0        1925.0
# 75%          10331.0        1975.0
# max          21650.0        2018.0

# %%
plt.style.use('seaborn')
sns.boxplot(data=df, x='Landsize', y='Price')

plt.show()

# %% [markdown]
# #### 2) Carilah data outlier dan beri penjelasan (insight) pada feature/column Distance ! Tambahkan plot untuk menampilkan adanya data outlier!

# %%
df.describe().T
# Out:
#                  count          mean            std          min  \
# Rooms          13580.0  2.937997e+00       0.955748      1.00000
# Price          13580.0  1.075684e+06  639310.724296  85000.00000
# Distance       13580.0  1.013778e+01       5.868725      0.00000
# Postcode       13580.0  3.105302e+03      90.676964   3000.00000
# Bedroom2       13580.0  2.914728e+00       0.965921      0.00000
# Bathroom       13580.0  1.534242e+00       0.691712      0.00000
# Car            13518.0  1.610075e+00       0.962634      0.00000
# Landsize       13580.0  5.584161e+02    3990.669241      0.00000
# BuildingArea    7130.0  1.519676e+02     541.014538      0.00000
# YearBuilt       8205.0  1.964684e+03      37.273762   1196.00000
# Lattitude      13580.0 -3.780920e+01       0.079260    -38.18255
# Longtitude     13580.0  1.449952e+02       0.103916    144.43181
# Propertycount  13580.0  7.454417e+03    4378.581772    249.00000
#
#                          25%            50%           75%           max
# Rooms               2.000000       3.000000  3.000000e+00  1.000000e+01
# Price          650000.000000  903000.000000  1.330000e+06  9.000000e+06
# Distance            6.100000       9.200000  1.300000e+01  4.810000e+01
# Postcode         3044.000000    3084.000000  3.148000e+03  3.977000e+03
# Bedroom2            2.000000       3.000000  3.000000e+00  2.000000e+01
# Bathroom            1.000000       1.000000  2.000000e+00  8.000000e+00
# Car                 1.000000       2.000000  2.000000e+00  1.000000e+01
# Landsize          177.000000     440.000000  6.510000e+02  4.330140e+05
# BuildingArea       93.000000     126.000000  1.740000e+02  4.451500e+04
# YearBuilt        1940.000000    1970.000000  1.999000e+03  2.018000e+03
# Lattitude         -37.856822     -37.802355 -3.775640e+01 -3.740853e+01
# Longtitude        144.929600     145.000100  1.450583e+02  1.455264e+02
# Propertycount    4380.000000    6555.000000  1.033100e+04  2.165000e+04

# %%
# Find the Upper Fence & Lower Fence
Q1 = df.describe()['Distance']['25%']
Q3 = df.describe()['Distance']['75%']
IQR = Q3 - Q1

Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)

# Data Outliers
df_outliers = df[(df['Distance'] < Lower_Fence) | (df['Distance'] > Upper_Fence)]

# %%
df_outliers['Distance'].sample(5)
# Out:
# 12275    24.7
# 12496    24.8
# 12627    25.5
# 9227     29.8
# 12210    25.5
# Name: Distance, dtype: float64

# %%
print(f"Upper Fence: {Upper_Fence}, Lower_Fence: {Lower_Fence}, max_outliers: {df_outliers['Distance'].max()}, min_outliers: {df_outliers['Distance'].min()}")
# Out:
# Upper Fence: 23.35, Lower_Fence: -4.250000000000002, max_outliers: 48.1, min_outliers: 23.5

# %%
plt.style.use('seaborn')
ax = sns.boxplot(x=df['Distance'])
plt.show()

# %% [markdown]
# - Data outliers dimulai sebarannya dari Distance: 23.35 hingga 48.1
# - Tidak ada data outliers yang berada di bawah batas bawah, karena memang tidak ada jarak yang lebih kecil dari 0

# %%
sns.scatterplot(data=df, x='Distance', y='Price', hue='Price')

plt.title('Scatter Plot: Distance & Price', size=15)

plt.show()

# %% [markdown]
# #### 3) Tampilkan distribusi (sebaran data) dalam bentuk plot yang tepat, untuk feature/column YearBuilt. Jelaskan insight apa yang Anda dapatkan di setiap plot tersebut!

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
# Create Feature YearBuiltInt (year in integer)
df['YearBuiltInt'] = df['YearBuilt'].fillna(0.0).astype(int)
df.sample(10)
# Out:
#                Suburb          Address  Rooms Type      Price Method  \
# 6128     Surrey Hills      4 Norris St      4    h  2860000.0      S
# 3427           Kealba     6 McGrath Cl      3    h   545000.0     SP
# 12542        Kew East    11 Coleman Av      4    h  2000000.0     VB
# 9953     Melton South     51 Andrew St      3    h   420000.0      S
# 3102     Hampton East      4 Besant St      3    h  1070000.0      S
# 9377   West Footscray       22 Hope St      3    h  1100000.0      S
# 1658       Canterbury  17 Irilbarra Rd      4    h  3400000.0      S
# 10104        Armadale  5/6 St James Rd      2    u   590000.0      S
# 8061          Malvern   11/5 Warner St      1    u   456000.0      S
# 11543  West Footscray    5/2 Ormond Rd      3    t   700000.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 6128        Marshall   7/11/2016      11.2    3127.0  ...  2.0     779.0
# 3427            Brad  16/07/2016      15.0    3021.0  ...  2.0     570.0
# 12542       Marshall   9/09/2017       7.3    3102.0  ...  1.0     704.0
# 9953   hockingstuart  24/06/2017      29.8    3338.0  ...  2.0     599.0
# 3102          Hodges  19/11/2016      14.5    3188.0  ...  3.0     583.0
# 9377          Biggin   3/06/2017       6.4    3012.0  ...  3.0     380.0
# 1658          Jellis  19/11/2016       9.0    3126.0  ...  4.0     845.0
# 10104         Jellis  27/05/2017       6.3    3143.0  ...  1.0     903.0
# 8061          Jellis   6/05/2017       7.4    3144.0  ...  1.0    4721.0
# 11543            Jas  15/07/2017       6.4    3012.0  ...  2.0     125.0
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# 6128          264.0     2014.0   Boroondara  -37.81850  145.08780
# 3427          163.0     1980.0     Brimbank  -37.73670  144.82460
# 12542           NaN        NaN          NaN  -37.79349  145.04611
# 9953            NaN        NaN       Melton  -37.69575  144.57894
# 3102          106.0     1970.0      Bayside  -37.94280  145.02960
# 9377          106.4     1945.0  Maribyrnong  -37.79194  144.87144
# 1658          411.0     2008.0   Boroondara  -37.81840  145.07020
# 10104           NaN        NaN  Stonnington  -37.85963  145.02077
# 8061            NaN        NaN  Stonnington  -37.85150  145.03720
# 11543         131.0     2013.0  Maribyrnong  -37.80735  144.87361
#
#                   Regionname  Propertycount YearBuiltInt
# 6128   Southern Metropolitan         5457.0         2014
# 3427    Western Metropolitan         1202.0         1980
# 12542  Southern Metropolitan         2671.0            0
# 9953        Western Victoria         4718.0            0
# 3102   Southern Metropolitan         2356.0         1970
# 9377    Western Metropolitan         5058.0         1945
# 1658   Southern Metropolitan         3265.0         2008
# 10104  Southern Metropolitan         4836.0            0
# 8061   Southern Metropolitan         4675.0            0
# 11543   Western Metropolitan         5058.0         2013
#
# [10 rows x 22 columns]

# %%
sns.distplot(df['YearBuiltInt'])
plt.title('Histogram: YearBuilt', size=20)

plt.xlabel('Year Built')
plt.ylabel('frequency')

plt.show()

# %%
len(df[df.YearBuiltInt==0]['YearBuilt']), len(df), round(len(df[df.YearBuiltInt==0]['YearBuilt'])/len(df)*100, 2)
# Out:
# (5375, 13580, 39.58)

# %% [markdown]
# - 39.58% (5375) data tahun tidak tersedia
# - dari data yang ada dapat diketahui bahwa tahun paling di mana properti paling banyak dibangun adalah di tahun 2000an dan menjelang tahun Masehi (menuju tahun 0)

# %%
# plt.hist(df['YearBuiltInt'])
# plt.title('Year Built', size=17)
# plt.xlabel('Year Built')
# plt.ylabel('Frequency')

# plt.show();

# %% [markdown]
# #### 4) Tampilkan perkembangan rata-rata harga (price) rumah berdasarkan tahun pembangunan rumah (Year) menggunakan plot yang tepat! Jelaskan (insight) perkembangan rata-rata harga rumah dari plot yang Anda buat!

# %%
plt.style.use('seaborn')
ax = sns.lineplot(data=df, x='YearBuilt', y='Price', estimator='mean')

# %% [markdown]
# - trend rata harga cenderung menurun dari tahun 1200 hingga sekitar beberapa dekade awal 1800. Trend ini disebabkan oleh banyak data kosong untuk tahun-tahun di periode tersebut.
# - di periode beberapa dekade setelah awal 1800, terlihat data harga rata-rata rumah berfluktuasi sangat ekstrem. Hal ini kemungkin dipicu oleh beberapa peristiwa penting seperti wabah flu spanyol (1918) dan dua Perang Dunia (1918 & 1942). Peristiwa yang bersifat katastrofi tersebut menyebabkan AS mengalami depresi dan kemungkinan memicu memicu trend menurun dari harga rata-rata properti.
# - di tahun 2008 juga terjadi krisis ekonomi yang salah satunya disebabkan oleh subprime mortgage bisa menjadi penyebab fluktuasi harga dengan trend menurun, namun setelah pulih, pasar properti pun kembali naik.

# %% [markdown]
# #### 5) Di antara Landsize, Distance, & Rooms, manakah feature/column yang memiliki nilai korelasi tertinggi pada feature/column Price? Jelaskan metode korelasi apa yang Anda gunakan, serta apa insight untuk perusahaan setelah mengetahui nilai korelasi tersebut?

# %% [markdown]
# #### 6) Temukan RegionName yang rata-rata harga (Price) propertinya paling tinggi, serta tampilkan RegionName dan rata-rata harga rumah dalam bentuk Barplot! Lalu, di region yang memiliki rata-rata harga properti tertinggi, carilah:
#
# - Lima CouncilArea yang memiliki rata-rata harga rumah tertinggi!
# - Tipe properti (Type) yang memiliki rata-rata harga rumah tertinggi!
# - Metode penjualan properti (Method) yang paling sering dilakukan!

# %%
df_Regionname = df[['Price', 'Regionname']].groupby(['Regionname'], as_index=False).mean()
df_Regionname
# Out:
#                    Regionname         Price
# 0        Eastern Metropolitan  1.104080e+06
# 1            Eastern Victoria  6.999808e+05
# 2       Northern Metropolitan  8.981711e+05
# 3           Northern Victoria  5.948293e+05
# 4  South-Eastern Metropolitan  9.229438e+05
# 5       Southern Metropolitan  1.372963e+06
# 6        Western Metropolitan  8.664205e+05
# 7            Western Victoria  3.975234e+05

# %%
print("Region yang memiliki harga rata-rata tertinggi adalah Southern Metropolitan")

fig = plt.figure(figsize=(18, 6))
sns.barplot(data=df_Regionname, x='Regionname', y='Price')
plt.title('Regionname vs Price', size=15)
plt.show()
# Out:
# Region yang memiliki harga rata-rata tertinggi adalah Southern Metropolitan

# %%
data = df[df['Regionname']=='Southern Metropolitan']
data.head()
# Out:
#          Suburb               Address  Rooms Type      Price Method  \
# 78  Albert Park        105 Kerferd Rd      2    h  1275000.0      S
# 79  Albert Park      85 Richardson St      2    h  1455000.0      S
# 80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 81  Albert Park          94 Graham St      3    h  1850000.0      S
# 82  Albert Park       396 Montague St      2    h  1436000.0      S
#
#           SellerG       Date  Distance  Postcode  ...  Bathroom  Car  \
# 78  hockingstuart  3/09/2016       3.3    3206.0  ...       1.0  0.0
# 79        Thomson  3/09/2016       3.3    3206.0  ...       1.0  0.0
# 80         Buxton  4/03/2017       3.3    3206.0  ...       2.0  0.0
# 81           Greg  4/03/2017       3.3    3206.0  ...       2.0  0.0
# 82             RT  4/03/2017       3.3    3206.0  ...       1.0  0.0
#
#     Landsize  BuildingArea  YearBuilt   CouncilArea Lattitude  Longtitude  \
# 78     120.0          82.0     1900.0  Port Phillip  -37.8459    144.9555
# 79     159.0           NaN        NaN  Port Phillip  -37.8450    144.9538
# 80     211.0         198.0     1890.0  Port Phillip  -37.8481    144.9499
# 81     128.0         133.0     1890.0  Port Phillip  -37.8452    144.9488
# 82     130.0          81.0     1900.0  Port Phillip  -37.8431    144.9565
#
#                Regionname Propertycount
# 78  Southern Metropolitan        3280.0
# 79  Southern Metropolitan        3280.0
# 80  Southern Metropolitan        3280.0
# 81  Southern Metropolitan        3280.0
# 82  Southern Metropolitan        3280.0
#
# [5 rows x 21 columns]

# %%
# Lima CouncilArea yang memiliki rata-rata harga rumah tertinggi!
data = df[df['Regionname']=='Southern Metropolitan']
df_CouncilArea = pd.crosstab(index=data['CouncilArea'], columns='Avg_Price', values=data['Price'], aggfunc='mean').round().sort_values(by='Avg_Price', ascending=False)
df_CouncilArea.head(6)

# 5 council area yang punya rata-rata harga rumah tertinggi
# Bayside
# Boroondara
# Whitehorse
# Stonnington
# Port Phillip
# --> Unavailable jika definisinya data tidak tersedia maka ini tidak masuk ke kategori
# Out:
# col_0         Avg_Price
# CouncilArea
# Bayside       1652168.0
# Boroondara    1646740.0
# Unavailable   1325000.0
# Whitehorse    1297237.0
# Stonnington   1293382.0
# Port Phillip  1144346.0

# %%
# Tipe properti (Type) yang memiliki rata-rata harga rumah tertinggi!
data = df[df['Regionname']=='Southern Metropolitan']
df_Type = pd.crosstab(index=data['Type'], columns='Avg_Price', values=data['Price'], aggfunc='mean').round().sort_values(by='Avg_Price', ascending=False)
df_Type.head()

# Type yang punya rata-rata harga rumah tertinggi adalah Type h
# Out:
# col_0  Avg_Price
# Type
# h      1802241.0
# t      1205404.0
# u       664860.0

# %%
# Metode penjualan properti (Method) yang paling sering dilakukan!
data = df[df['Regionname']=='Southern Metropolitan']
df_Method = pd.crosstab(index=data['Method'], columns='Count').sort_values(by=['Count'], ascending=False)
df_Method.head()

# Metode penjualan properti (Method) yang paling sering dilakukan adalah S
# Out:
# col_0   Count
# Method
# S        3038
# PI        671
# VB        572
# SP        376
# SA         38

# %% [markdown]
# #### 7) Lakukan Uji Hipotesis untuk menguji apakah ada perbedaan harga properti antar Region Name!

# %%
df_Price = df[['Price', 'Regionname']].groupby(['Regionname'], as_index=False).mean().round()
df_Price
# Out:
#                    Regionname      Price
# 0        Eastern Metropolitan  1104080.0
# 1            Eastern Victoria   699981.0
# 2       Northern Metropolitan   898171.0
# 3           Northern Victoria   594829.0
# 4  South-Eastern Metropolitan   922944.0
# 5       Southern Metropolitan  1372963.0
# 6        Western Metropolitan   866421.0
# 7            Western Victoria   397523.0
